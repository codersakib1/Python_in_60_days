# %%
#Python Function Recursion. Recursive Function

# %%
def facto(x):
    if x==0:
        return 1
    return x* facto(x-1)

# %%
facto(5)
# Out:
# 120

# %%
def web():
    print("https://codersakib1.github.io/website1/")
 

web()
# Out:
# https://codersakib1.github.io/website1/

# %%
def web():
    print("https://codersakib1.github.io/website1/")
    web()

web()
# Out:
# https://codersakib1.github.io/website1/
# https://codersakib1.github.io/website1/
# https://codersakib1.github.io/website1/
# https://codersakib1.github.io/website1/
# https://codersakib1.github.io/website1/
# https://codersakib1.github.io/website1/
# https://codersakib1.github.io/website1/
# https://codersakib1.github.io/website1/
# https://codersakib1.github.io/website1/
# https://codersakib1.github.io/website1/
# https://codersakib1.github.io/website1/
# https://codersakib1.github.io/website1/
# https://codersakib1.github.io/website1/
# https://codersakib1.github.io/website1/
# https://codersakib1.github.io/website1/
# https://codersakib1.github.io/website1/
# https://codersakib1.github.io/website1/
# https://codersakib1.github.io/website1/
# https://codersakib1.github.io/website1/
# https://codersakib1.github.io/website1/
# https://codersakib1.github.io/website1/
# https://codersakib1.github.io/website1/
# https://codersakib1.github.io/website1/
# ...

# %%
import sys
sys.getrecursionlimit()
# Out:
# 3000
